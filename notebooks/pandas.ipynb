# %%
import pandas
from topopt.monitoring import MetricTracker
from pathlib import Path

trained_neural_field = Path("../outputs/12-31_15-42-16_neural_field")
data = MetricTracker.load(npz_path=trained_neural_field / "metrics_log.npz")
shapes = {k: v.shape for k, v in data.items()}
# Out:
# {'al_linear': (100, 6), 'al_penalty': (100, 6), 'al_quadratic': (100, 6), 'compliance': (100, 6), 'constraint_violation': (100, 6), 'effective_lr': (100, 6), 'lambda': (100, 6), 'lambda_update': (100, 6), 'learning_rate_scale': (100, 6), 'loss': (100, 6), 'optimisation_step_wall_time_s': (96, 1), 'volume_fraction_error': (100, 6)}
